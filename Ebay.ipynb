# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Readong the CSV and changing to df
df_ebay = pd.read_csv(r'C:\Users\stephensimpson.CORP\Desktop\Python\eBay.csv', on_bad_lines='skip')

# %%
print(df_ebay)
# Out:
#                                         Listing title  eBay item ID  \
# 0      NEW SEALED 2021 Mosaic Basketball Fat Pack NBA  2.550000e+11
# 1   Myles Garrett Browns 2020 Panini Encased GJ-9 ...  2.550000e+11
# 2   2010-11 Prestige Stat Stars Materials Patch Je...  2.550000e+11
# 3   2011 O-Pee-Chee Materials Malkin Sidney Crosby...  2.550000e+11
# 4   Bakugan Sabator/Golden Shot Combat Set Gundali...  2.550000e+11
# ..                                                ...           ...
# 92  Spyro A Hero's Tail (Nintendo GameCube) CIB CO...  2.560000e+11
# 93  Tony Hawk's Underground 2 (Nintendo GameCube) ...  2.560000e+11
# 94  Transformers Dark of the Moon Movie Leader Cla...  2.560000e+11
# 95  Gray Nintendo 64 N64 Authentic Official Origin...  2.560000e+11
# 96  Legend of Zelda: The Wind Waker (GameCube) Com...  2.560000e+11
#
#     Quantity sold Total sales (Includes taxes) Item sales  \
# 0               2                      $47.63     $44.38
# 1               1                      $59.99     $59.99
# 2               1                      $70.60     $64.99
# 3               1                      $37.44     $34.99
# 4               1                      $35.18     $32.99
# ..            ...                          ...        ...
# 92              1                      $21.34     $19.99
# 93              1                      $13.55     $12.49
# 94              1                      $81.46     $74.99
# 95              1                      $27.00     $24.99
# 96              1                      $79.86     $74.99
#
#    Taxes and government fees paid by buyer to you  \
# 0                                          $0.00
# 1                                          $0.00
# 2                                          $0.00
# 3                                          $0.00
# 4                                          $0.00
# ..                                            ...
# 92                                         $0.00
# 93                                         $0.00
# 94                                         $0.00
# 95                                         $0.00
# 96                                         $0.00
#
#    Taxes and government fees paid by buyer to eBay  \
# 0                                           $3.25
# 1                                           $0.00
# 2                                           $5.61
# 3                                           $2.45
# 4                                           $2.19
# ..                                             ...
# 92                                          $1.35
# 93                                          $1.06
# 94                                          $6.47
# 95                                          $2.01
# 96                                          $4.87
#
#    Shipping and handling paid by buyer to you Total selling costs  \
# 0                                      $0.00              $13.67
# 1                                      $0.00              $11.90
# 2                                      $0.00              $12.41
# 3                                      $0.00               $8.71
# 4                                      $0.00               $8.43
# ..                                        ...                 ...
# 92                                     $0.00               $6.77
# 93                                     $0.00               $5.77
# 94                                     $0.00              $15.64
# 95                                     $0.00               $7.93
# 96                                     $0.00              $14.48
#
#    Insertion fees  ... Promoted Listings Standard fees  \
# 0          $0.00   ...                          $0.00
# 1          $0.00   ...                          $0.00
# 2          $0.00   ...                          $0.00
# 3          $0.00   ...                          $0.00
# 4          $0.00   ...                          $0.00
# ..            ...  ...                             ...
# 92         $0.00   ...                          $0.00
# 93         $0.00   ...                          $0.00
# 94         $0.00   ...                          $0.00
# 95         $0.00   ...                          $0.00
# 96         $0.00   ...                          $0.00
#
#    Promoted Listings Advanced fees Promoted Listings Express fees  \
# 0                           $0.00                          $0.00
# 1                           $0.00                          $0.00
# 2                           $0.00                          $0.00
# 3                           $0.00                          $0.00
# 4                           $0.00                          $0.00
# ..                             ...                            ...
# 92                          $0.00                          $0.00
# 93                          $0.00                          $0.00
# 94                          $0.00                          $0.00
# 95                          $0.00                          $0.00
# 96                          $0.00                          $0.00
#
#    International fees Other eBay fees Deposit processing fees Fee credits  \
# 0              $0.00           $0.00                   $0.00       $0.00
# 1              $0.00           $0.00                   $0.00       $0.00
# 2              $0.00           $0.00                   $0.00       $0.00
# 3              $0.00           $0.00                   $0.00       $0.00
# 4              $0.00           $0.00                   $0.00       $0.00
# ..                ...             ...                     ...         ...
# 92             $0.00           $0.00                   $0.00       $0.00
# 93             $0.00           $0.00                   $0.00       $0.00
# 94             $0.00           $0.00                   $0.00       $0.00
# 95             $0.00           $0.00                   $0.00       $0.00
# 96             $0.00           $0.00                   $0.00       $0.00
#
#    Shipping labels cost (Amount you paid to buy shipping labels on eBay)  \
# 0                                              $7.18
# 1                                              $3.86
# 2                                              $3.39
# 3                                              $3.58
# 4                                              $3.79
# ..                                                ...
# 92                                             $3.72
# 93                                             $3.72
# 94                                             $4.83
# 95                                             $4.15
# 96                                             $3.88
#
#    Net sales (Net of taxes and selling costs) Average Selling price
# 0                                     $30.71                $23.82
# 1                                     $48.09                $59.99
# 2                                     $52.58                $70.60
# 3                                     $26.28                $37.44
# 4                                     $24.56                $35.18
# ..                                        ...                   ...
# 92                                    $13.22                $21.34
# 93                                     $6.72                $13.55
# 94                                    $59.35                $81.46
# 95                                    $17.06                $27.00
# 96                                    $60.51                $79.86
#
# [97 rows x 22 columns]

# %%
df_ebay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 22 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Listing title                                                          97 non-null     object
#  1   eBay item ID                                                           97 non-null     float64
#  2   Quantity sold                                                          97 non-null     int64
#  3   Total sales (Includes taxes)                                           97 non-null     object
#  4   Item sales                                                             97 non-null     object
#  5   Taxes and government fees paid by buyer to you                         97 non-null     object
#  6   Taxes and government fees paid by buyer to eBay                        97 non-null     object
#  7   Shipping and handling paid by buyer to you                             97 non-null     object
#  8   Total selling costs                                                    97 non-null     object
#  9   Insertion fees                                                         97 non-null     object
#  10  Optional listing upgrade fees                                          97 non-null     object
#  11  Final value fees                                                       97 non-null     object
#  12  Promoted Listings Standard fees                                        97 non-null     object
#  13  Promoted Listings Advanced fees                                        97 non-null     object
#  14  Promoted Listings Express fees                                         97 non-null     object
#  15  International fees                                                     97 non-null     object
#  16  Other eBay fees                                                        97 non-null     object
#  17  Deposit processing fees                                                97 non-null     object
#  18  Fee credits                                                            97 non-null     object
#  19  Shipping labels cost (Amount you paid to buy shipping labels on eBay)  97 non-null     object
#  20  Net sales (Net of taxes and selling costs)                             97 non-null     object
#  21  Average Selling price                                                  97 non-null     object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 16.8+ KB

# %%
df_ebay.shape
# Out:
# (97, 22)

# %%
df_ebay.head()
# Out:
#                                        Listing title  eBay item ID  \
# 0     NEW SEALED 2021 Mosaic Basketball Fat Pack NBA  2.550000e+11
# 1  Myles Garrett Browns 2020 Panini Encased GJ-9 ...  2.550000e+11
# 2  2010-11 Prestige Stat Stars Materials Patch Je...  2.550000e+11
# 3  2011 O-Pee-Chee Materials Malkin Sidney Crosby...  2.550000e+11
# 4  Bakugan Sabator/Golden Shot Combat Set Gundali...  2.550000e+11
#
#    Quantity sold Total sales (Includes taxes) Item sales  \
# 0              2                      $47.63     $44.38
# 1              1                      $59.99     $59.99
# 2              1                      $70.60     $64.99
# 3              1                      $37.44     $34.99
# 4              1                      $35.18     $32.99
#
#   Taxes and government fees paid by buyer to you  \
# 0                                         $0.00
# 1                                         $0.00
# 2                                         $0.00
# 3                                         $0.00
# 4                                         $0.00
#
#   Taxes and government fees paid by buyer to eBay  \
# 0                                          $3.25
# 1                                          $0.00
# 2                                          $5.61
# 3                                          $2.45
# 4                                          $2.19
#
#   Shipping and handling paid by buyer to you Total selling costs  \
# 0                                     $0.00              $13.67
# 1                                     $0.00              $11.90
# 2                                     $0.00              $12.41
# 3                                     $0.00               $8.71
# 4                                     $0.00               $8.43
#
#   Insertion fees  ... Promoted Listings Standard fees  \
# 0         $0.00   ...                          $0.00
# 1         $0.00   ...                          $0.00
# 2         $0.00   ...                          $0.00
# 3         $0.00   ...                          $0.00
# 4         $0.00   ...                          $0.00
#
#   Promoted Listings Advanced fees Promoted Listings Express fees  \
# 0                          $0.00                          $0.00
# 1                          $0.00                          $0.00
# 2                          $0.00                          $0.00
# 3                          $0.00                          $0.00
# 4                          $0.00                          $0.00
#
#   International fees Other eBay fees Deposit processing fees Fee credits  \
# 0             $0.00           $0.00                   $0.00       $0.00
# 1             $0.00           $0.00                   $0.00       $0.00
# 2             $0.00           $0.00                   $0.00       $0.00
# 3             $0.00           $0.00                   $0.00       $0.00
# 4             $0.00           $0.00                   $0.00       $0.00
#
#   Shipping labels cost (Amount you paid to buy shipping labels on eBay)  \
# 0                                             $7.18
# 1                                             $3.86
# 2                                             $3.39
# 3                                             $3.58
# 4                                             $3.79
#
#   Net sales (Net of taxes and selling costs) Average Selling price
# 0                                    $30.71                $23.82
# 1                                    $48.09                $59.99
# 2                                    $52.58                $70.60
# 3                                    $26.28                $37.44
# 4                                    $24.56                $35.18
#
# [5 rows x 22 columns]

# %%
#Cleaning column names
df_ebay.columns = df_ebay.columns.str.replace(' ','')
df_ebay.columns = df_ebay.columns.str.replace(' ','_').str.lower()

# %%
#Renaming columns
df_ebay = df_ebay.rename(columns={'totalsales(includestaxes)': 'totalsales', 'taxesandgovernmentfeespaidbybuyertoyou': 'buyertaxesandgovtoyou', 'taxesandgovernmentfeespaidbybuyertoebay': 'buyertaxesandgovtoebay','shippinglabelscost(amountyoupaidtobuyshippinglabelsonebay)':'yourshippingcost','netsales(netoftaxesandsellingcosts)':'netsales'})

# %%
#dropping columns
to_drop = ['promotedlistingsstandardfees','promotedlistingsadvancedfees', 'promotedlistingsexpressfees', 'optionallistingupgradefees', 'finalvaluefees','insertionfees', 'depositprocessingfees']
df_ebay.drop(to_drop, inplace=True, axis=1)

# %%
df_ebay['totalsales'] = df_ebay['totalsales'].replace('\$|,', '', regex=True)
df_ebay['itemsales'] = df_ebay['itemsales'].replace('\$|,', '', regex=True)
df_ebay['buyertaxesandgovtoyou'] = df_ebay['buyertaxesandgovtoyou'].replace('\$|,', '', regex=True)
df_ebay['buyertaxesandgovtoebay'] = df_ebay['buyertaxesandgovtoebay'].replace('\$|,', '', regex=True)
df_ebay['shippingandhandlingpaidbybuyertoyou'] = df_ebay['shippingandhandlingpaidbybuyertoyou'].replace('\$|,', '', regex=True)
df_ebay['totalsellingcosts'] = df_ebay['totalsellingcosts'].replace('\$|,', '', regex=True)
df_ebay['internationalfees'] = df_ebay['internationalfees'].replace('\$|,', '', regex=True)
df_ebay['otherebayfees'] = df_ebay['otherebayfees'].replace('\$|,', '', regex=True)
df_ebay['feecredits'] = df_ebay['feecredits'].replace('\$|,', '', regex=True)
df_ebay['yourshippingcost'] = df_ebay['yourshippingcost'].replace('\$|,', '', regex=True)
df_ebay['averagesellingprice'] = df_ebay['averagesellingprice'].replace('\$|,', '', regex=True)

# %%
#Had to change negatives to - for netsales because of a return, wouldn't allow me to make it an int.
df_ebay['netsales'] = df_ebay['netsales'].replace( '[\$,)]','', regex=True )
df_ebay['netsales'] = df_ebay['netsales'].replace( '[(]','-',   regex=True )

# %%
#Looking at the data types
print(df_ebay.dtypes)
# Out:
# listingtitle                            object
# ebayitemid                             float64
# quantitysold                             int64
# totalsales                               int32
# itemsales                                int32
# buyertaxesandgovtoyou                    int32
# buyertaxesandgovtoebay                   int32
# shippingandhandlingpaidbybuyertoyou      int32
# totalsellingcosts                        int32
# internationalfees                        int32
# otherebayfees                            int32
# feecredits                               int32
# yourshippingcost                         int32
# netsales                                 int32
# averagesellingprice                      int32
# dtype: object

# %%
#Cleaning data and creating function to get rid of spaces in data
def whitespace_remover(dataframe):
   
    # iterating over the columns
    for i in df_ebay.columns:
         
        # checking datatype of each columns
        if df_ebay[i].dtype == 'object':
             
            # applying strip function on column
            df_ebay[i] = df_ebay[i].map(str.strip)
        else:
             
            # if condn. is False then it will do nothing.
            pass
    whitespace_remover(df_ebay)

# %%
#Converting all to float, before integer
df_ebay = df_ebay.astype({'totalsales':'float'})
df_ebay = df_ebay.astype({'itemsales':'float'})
df_ebay = df_ebay.astype({'buyertaxesandgovtoyou':'float'})
df_ebay = df_ebay.astype({'buyertaxesandgovtoebay':'float'})
df_ebay = df_ebay.astype({'shippingandhandlingpaidbybuyertoyou':'float'})
df_ebay = df_ebay.astype({'totalsellingcosts':'float'})
df_ebay = df_ebay.astype({'internationalfees':'float'})
df_ebay = df_ebay.astype({'otherebayfees':'float'})
df_ebay = df_ebay.astype({'feecredits':'float'})
df_ebay = df_ebay.astype({'yourshippingcost':'float'})
df_ebay = df_ebay.astype({'averagesellingprice':'float'})
df_ebay = df_ebay.astype({'netsales':'float'})

# %%
#Converting all to integer
df_ebay = df_ebay.astype({'totalsales':'int'})
df_ebay = df_ebay.astype({'itemsales':'int'})
df_ebay = df_ebay.astype({'buyertaxesandgovtoyou':'int'})
df_ebay = df_ebay.astype({'buyertaxesandgovtoebay':'int'})
df_ebay = df_ebay.astype({'shippingandhandlingpaidbybuyertoyou':'int'})
df_ebay = df_ebay.astype({'totalsellingcosts':'int'})
df_ebay = df_ebay.astype({'internationalfees':'int'})
df_ebay = df_ebay.astype({'otherebayfees':'int'})
df_ebay = df_ebay.astype({'feecredits':'int'})
df_ebay = df_ebay.astype({'yourshippingcost':'int'})
df_ebay = df_ebay.astype({'averagesellingprice':'int'})
df_ebay = df_ebay.astype({'netsales':'int'})

# %%
print(df_ebay.dtypes)
# Out:
# listingtitle                            object
# ebayitemid                             float64
# quantitysold                             int64
# totalsales                               int32
# itemsales                                int32
# buyertaxesandgovtoyou                    int32
# buyertaxesandgovtoebay                   int32
# shippingandhandlingpaidbybuyertoyou      int32
# totalsellingcosts                        int32
# internationalfees                        int32
# otherebayfees                            int32
# feecredits                               int32
# yourshippingcost                         int32
# netsales                                 int32
# averagesellingprice                      int32
# dtype: object

# %%
df_ebay.describe()
# Out:
#          ebayitemid  quantitysold  totalsales   itemsales  \
# count  9.700000e+01     97.000000   97.000000   97.000000
# mean   2.554536e+11      1.010309   54.835052   50.824742
# std    5.004294e+08      0.101535   52.888972   49.303484
# min    2.550000e+11      1.000000    0.000000    0.000000
# 25%    2.550000e+11      1.000000   26.000000   24.000000
# 50%    2.550000e+11      1.000000   38.000000   35.000000
# 75%    2.560000e+11      1.000000   64.000000   59.000000
# max    2.560000e+11      2.000000  325.000000  299.000000
#
#        buyertaxesandgovtoyou  buyertaxesandgovtoebay  \
# count                   97.0               97.000000
# mean                     0.0                3.020619
# std                      0.0                3.915725
# min                      0.0                0.000000
# 25%                      0.0                1.000000
# 50%                      0.0                2.000000
# 75%                      0.0                4.000000
# max                      0.0               25.000000
#
#        shippingandhandlingpaidbybuyertoyou  totalsellingcosts  \
# count                            97.000000          97.000000
# mean                              0.268041          10.195876
# std                               1.906761           6.315720
# min                               0.000000           0.000000
# 25%                               0.000000           7.000000
# 50%                               0.000000           8.000000
# 75%                               0.000000          12.000000
# max                              16.000000          44.000000
#
#        internationalfees  otherebayfees  feecredits  yourshippingcost  \
# count               97.0           97.0   97.000000         97.000000
# mean                 0.0            0.0    0.371134          3.319588
# std                  0.0            0.0    2.218857          1.432847
# min                  0.0            0.0    0.000000          0.000000
# 25%                  0.0            0.0    0.000000          3.000000
# 50%                  0.0            0.0    0.000000          3.000000
# 75%                  0.0            0.0    0.000000          4.000000
# max                  0.0            0.0   15.000000         12.000000
#
#          netsales  averagesellingprice
# count   97.000000            97.000000
# mean    40.845361            54.587629
# std     43.757223            52.982063
# min     -3.000000             0.000000
# 25%     17.000000            24.000000
# 50%     26.000000            38.000000
# 75%     47.000000            64.000000
# max    255.000000           325.000000

# %%
#Total sales above $24.99
df_ebay.netsales >= 24.99
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 92    False
# 93    False
# 94     True
# 95    False
# 96     True
# Name: netsales, Length: 97, dtype: bool

# %%
#Sorting total sales
df_ebay.sort_values("netsales")
# Out:
#                                          listingtitle    ebayitemid  \
# 54  2007 Topps Chrome Blue Refractors Marshawn Lyn...  2.560000e+11
# 13  joe montana 1995 starting lineup Kansas City C...  2.550000e+11
# 12  LION KING Simba and Nala PLASTIC TABLE COVER ~...  2.550000e+11
# 93  Tony Hawk's Underground 2 (Nintendo GameCube) ...  2.560000e+11
# 84       iClicker 2 Student Remote Classroom Response  2.560000e+11
# ..                                                ...           ...
# 45     2020 Donruss Optic Ben Roethlisberger Downtown  2.550000e+11
# 53  2007 Topps Chrome #264 JOE THOMAS Rookie Red R...  2.560000e+11
# 37  Nike Dunk Low Paisley Pack Worn Blue (W) Size ...  2.550000e+11
# 48  Nike Dunk Low Retro White Black Panda (Women) ...  2.550000e+11
# 15  2020 Upper Deck Goodwin Champions Darius Garla...  2.550000e+11
#
#     quantitysold  totalsales  itemsales  buyertaxesandgovtoyou  \
# 54             1           0          0                      0
# 13             1          10          9                      0
# 12             1          10          9                      0
# 93             1          13         12                      0
# 84             1          16         15                      0
# ..           ...         ...        ...                    ...
# 45             1         171        160                      0
# 53             1         225        210                      0
# 37             1         233        219                      0
# 48             1         256        239                      0
# 15             1         325        299                      0
#
#     buyertaxesandgovtoebay  shippingandhandlingpaidbybuyertoyou  \
# 54                       0                                    0
# 13                       0                                    0
# 12                       0                                    0
# 93                       1                                    0
# 84                       1                                    0
# ..                     ...                                  ...
# 45                      11                                    0
# 53                      15                                    0
# 37                      13                                    0
# 48                      16                                    0
# 15                      25                                    0
#
#     totalsellingcosts  internationalfees  otherebayfees  feecredits  \
# 54                  3                  0              0           6
# 13                  5                  0              0           0
# 12                  5                  0              0           0
# 93                  5                  0              0           0
# 84                  6                  0              0           0
# ..                ...                ...            ...         ...
# 45                 25                  0              0           0
# 53                 32                  0              0           0
# 37                 26                  0              0           0
# 48                 29                  0              0           0
# 15                 44                  0              0           0
#
#     yourshippingcost  netsales  averagesellingprice
# 54                 3        -3                    0
# 13                 3         4                   10
# 12                 3         4                   10
# 93                 3         6                   13
# 84                 3         8                   16
# ..               ...       ...                  ...
# 45                 3       134                  171
# 53                 3       177                  225
# 37                 8       193                  233
# 48                 8       210                  256
# 15                 3       255                  325
#
# [97 rows x 15 columns]

# %%
#Not a good graph
import matplotlib.pyplot as plt
matplotlib.style.use('fivethirtyeight')
df_ebay['totalsales'].sort_values(ascending=0)[:10].plot(kind='barh')
plt.xlabel('Price')
plt.ylabel('Item Number')
plt.title('Top 10 Items Sold')
# Out:
# Text(0.5, 1.0, 'Top 10 Items Sold')

# %%
#Recent 5 items sold
df_ebay.plot(x='listingtitle', y='netsales', kind = 'barh', legend=False, title='Recent Net Sales of Items Sold')
plt.ylim(92,97 )
plt.xlim(0,70 )
plt.xlabel('Price')
plt.ylabel('Item')
plt.show()

# %%
#Experimenting
df_ebay.groupby(by = {1: "Myles Garrett Browns 2020 Panini Encased", 96: "Legend of Zelda: The Wind Waker"}).mean().T.plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %%
total_sales = df_ebay.totalsales.sum()
total_net = df_ebay.netsales.sum()
total_cost = df_ebay.totalsellingcosts.sum()

print(total_sales)
print(total_net)
print(total_cost)
# Out:
# 5319
# 3962
# 989

# %%
avg_net_sales = df_ebay.netsales.mean()
avg_shippingcost = df_ebay.yourshippingcost.mean()

print(avg_net_sales)
print(avg_shippingcost)
# Out:
# 40.845360824742265
# 3.3195876288659796
